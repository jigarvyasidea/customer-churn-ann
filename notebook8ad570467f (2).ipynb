# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv

# %%
df = pd.read_csv('/kaggle/input/credit-card-customer-churn-prediction/Churn_Modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
# we will notice here is 10K row and 4 columns
df.head(1)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              1          1               1        101348.88
#
#    Exited
# 0       1

# %% [markdown]
# # let see the columns
# # the first columns is **RowNumber** :- here is uniue row number of that customer but if think right now i dont think it Usefull for me .
# # coluns 2 it woud me customerID :- our goal to predict how many how many customer stay in bank or leave bank predict
# # surname :- so in this perticulra columns they store the sir name of customer what you thinks it usefull umm surname let condier for now
# # creditScore :_ in this feature /colums of dataset in this perticular columns we have creadit card
# # new columns is Geography :- here is mention waht geography therey are from like in that colums  mention country we can say .
# # age :- this columns you might we used as feature how logic you think in your mind that depand
# # Balence :- here it metnin exectly how much balance in that accuound this migth be helpfull if  used dont have good budget may be it help deep learnig model to predit
# # NumberofProduct :- in this columns it mention how many bank product that customer is using in your mind defintly pop up code ummm ..number of  PRoduct what do you mena ...its like creadit card , dabit card etc kind of product
#
# isActiveMenebert : - here many be mentiio kuej

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# in this perticular dataset we see 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 5836       5837    15617419          Roberts          618   Germany  Female
# 8128       8129    15682928  Chiazagomekpere          695     Spain    Male
# 4322       4323    15681697            Rueda          508    France    Male
# 2538       2539    15752838            Lucas          723     Spain    Male
# 9549       9550    15772604        Chiemezie          578     Spain    Male
# 1410       1411    15710164            P'eng          523    France  Female
# 7693       7694    15602043           Buccho          770   Germany  Female
# 4577       4578    15703979            Evans          580   Germany    Male
# 6734       6735    15723318          Mactier          619    France  Female
# 646         647    15730830             Dale          752    France  Female
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
df['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
# let see how many customer existe in bank and how many leave the bank 
df['Exited'].value_counts

#sns.pie(df['Exited']_value_counts())
# Out:
# <bound method IndexOpsMixin.value_counts of 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64>

# %% [markdown]
# # we will notics here is
# 7963 people accound existe in pank
# and
# 1. **2037** peole exited the bank or remove arround from the bank

# %% [markdown]
# # here we will see in Geography that we have mutplitiple  category
# like France , Germany and Spain.

# %%
df.sample(1)
# Out:
#       RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 4490       4491    15792646  Trentino          647     Spain  Female   64
#
#       Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 4490       1  91216.0              1          1               1
#
#       EstimatedSalary  Exited
# 4490         41800.18       0

# %% [markdown]
# # Now on that columnes where we haave categrical data
# # i convert that data into numcial
# # eocing need so i apply one hot encoding
# # on columns if you dont to apply one hont encoding use used function name
# pd.get_dummies()

# %%
df.shape
# Out:
# (10000, 14)

# %%
df = pd.get_dummies(df, columns=['Gender', 'Geography'], drop_first=True)

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
# ...

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'])
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# ...

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore  Age  Tenure    Balance  \
# 0             1    15634602   Hargrave          619   42       2       0.00
# 1             2    15647311       Hill          608   41       1   83807.86
# 2             3    15619304       Onio          502   42       8  159660.80
# 3             4    15701354       Boni          699   39       1       0.00
# 4             5    15737888   Mitchell          850   43       2  125510.82
# ...         ...         ...        ...          ...  ...     ...        ...
# 9995       9996    15606229   Obijiaku          771   39       5       0.00
# 9996       9997    15569892  Johnstone          516   35      10   57369.61
# 9997       9998    15584532        Liu          709   36       7       0.00
# 9998       9999    15682355  Sabbatini          772   42       3   75075.31
# 9999      10000    15628319     Walker          792   28       4  130142.79
#
# ...

# %%
df.drop(columns=['RowNumber', 'CustomerId', 'Surname'] , inplace = True )

# %%
df.head(4)
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# 0               1        101348.88       1            0                  0
# 1               1        112542.58       0            0                  0
# 2               0        113931.57       1            0                  0
# 3               0         93826.63       0            0                  0
#
#    Geography_Spain
# 0                0
# 1                1
# 2                0
# 3                0

# %%
df.head(2)
# Out:
#    CreditScore  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.00              1          1
# 1          608   41       1  83807.86              1          0
#
#    IsActiveMember  EstimatedSalary  Exited  Gender_Male  Geography_Germany  \
# 0               1        101348.88       1            0                  0
# 1               1        112542.58       0            0                  0
#
#    Geography_Spain
# 0                0
# 1                1

# %%
# let decide input and output

x = df.drop(columns=['Exited'])
y = df['Exited']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test , y_train , y_test = train_test_split(x , y, test_size = 0.2 , random_state = 42 )

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_trf = scaler.fit_transform(x_train)
X_test_trf = scaler.transform(x_test)

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential 
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# %%
model.add(Dense(11,activation='relu',input_dim=11))
model.add(Dense(11,activation='sigmoid'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 11)                132
# _________________________________________________________________
# dense_1 (Dense)              (None, 11)                132
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 12
# ...
# Total params: 276
# Trainable params: 276
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
history = model.fit(x_train,y_train,batch_size=50,epochs=200,verbose=1,validation_split=0.2)
# Out:
# Epoch 1/200
# 128/128 [==============================] - 1s 5ms/step - loss: 0.6589 - accuracy: 0.6186 - val_loss: 0.5876 - val_accuracy: 0.6906
# Epoch 2/200
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5569 - accuracy: 0.7437 - val_loss: 0.5212 - val_accuracy: 0.7987
# Epoch 3/200
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5195 - accuracy: 0.7934 - val_loss: 0.5078 - val_accuracy: 0.7987
# Epoch 4/200
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.7934 - val_loss: 0.5053 - val_accuracy: 0.7987
# Epoch 5/200
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5103 - accuracy: 0.7934 - val_loss: 0.5001 - val_accuracy: 0.7987
# Epoch 6/200
# 128/128 [==============================] - 0s 3ms/step - loss: 0.5121 - accuracy: 0.7934 - val_loss: 0.4989 - val_accuracy: 0.7987
# Epoch 7/200
# ...

# %%
y_log = model.predict(x_test)

# %%
y_pred = np.where(y_log >0.5 , 1 , 0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred )
# Out:
# 0.8035

# %%
# we will see the acuureacy of out current model is 80% based on data they instally make feature
